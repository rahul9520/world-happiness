# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np

# %%
# Read in cleanned up data
data = pd.read_csv('happines')

# Group data by average happiness score over the years
data_agg = data.groupby('Country').mean()

data_agg
# Out:
#              Happiness Rank  Happiness Score  Standard Error  \
# Country
# Afghanistan           153.0            3.575         0.03084
# Albania                95.0            4.959         0.05013
# Algeria                68.0            5.605         0.05099
# Angola                137.0            4.033         0.04758
# Argentina              30.0            6.574         0.04612
# ...                     ...              ...             ...
# Venezuela              23.0            6.810         0.06476
# Vietnam                75.0            5.360         0.03107
# Yemen                 136.0            4.077         0.04367
# Zambia                 85.0            5.129         0.06988
# Zimbabwe              115.0            4.610         0.04290
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Afghanistan                   0.31982  0.30285                   0.30335
# Albania                       0.87867  0.80434                   0.81325
# Algeria                       0.93929  1.07772                   0.61766
# Angola                        0.75778  0.86040                   0.16683
# Argentina                     1.05351  1.24823                   0.78723
# ...                               ...      ...                       ...
# Venezuela                     1.04424  1.25596                   0.72052
# Vietnam                       0.63216  0.91226                   0.74676
# Yemen                         0.54649  0.68093                   0.40064
# Zambia                        0.47038  0.91612                   0.29924
# Zimbabwe                      0.27100  1.03276                   0.33475
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# Afghanistan  0.23414                        0.09719     0.36510
# Albania      0.35733                        0.06413     0.14272
# Algeria      0.28579                        0.17383     0.07822
# Angola       0.10384                        0.07122     0.12344
# Argentina    0.44974                        0.08484     0.11451
# ...              ...                            ...         ...
# Venezuela    0.42908                        0.11069     0.05841
# Vietnam      0.59444                        0.10441     0.16860
# Yemen        0.35571                        0.07854     0.09131
# Zambia       0.48827                        0.12468     0.19591
# Zimbabwe     0.25861                        0.08079     0.18987
#
#              Dystopia Residual
# Country
# Afghanistan            1.95210
# Albania                1.89894
# Algeria                2.43209
# Angola                 1.94939
# Argentina              2.83600
# ...                        ...
# Venezuela              3.19131
# Vietnam                2.20173
# Yemen                  1.92313
# Zambia                 2.63430
# Zimbabwe               2.44191
#
# [158 rows x 10 columns]

# %%
# Create a scatter plot with a regression line for Economy GDP per Capita
x_values = data_agg['Happiness Score']
y_values = data_agg['Economy (GDP per Capita)']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Economy (GDP per Capita)')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
plt.show()
# Out:
# The r-squared is: 0.6099071541531224
# y = 0.27x + -0.63

# %%
# Create a scatter plot with a regression line for Health (Life Expectancy)
x_values = data_agg['Happiness Score']
y_values = data_agg['Health (Life Expectancy)']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Health (Life Expectancy)')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
plt.show()
# Out:
# The r-squared is: 0.5244650535503468
# y = 0.16x + -0.21

# %%
# Create a scatter plot with a regression line for Family
x_values = data_agg['Happiness Score']
y_values = data_agg['Family']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Family')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)

plt.show()
# Out:
# The r-squared is: 0.548496058174137
# y = 0.18x + 0.04

# %%
# Create a scatter plot with a regression line for Freedom
x_values = data_agg['Happiness Score']
y_values = data_agg['Freedom']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Freedom')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
plt.show()
# Out:
# The r-squared is: 0.32286363164327897
# y = 0.07x + 0.03

# %%
# Create a scatter plot with a regression line for Trust (Government Corruption)
x_values = data_agg['Happiness Score']
y_values = data_agg['Trust (Government Corruption)']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Trust (Government Corruption)')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
plt.show()
# Out:
# The r-squared is: 0.15618192066670003
# y = 0.04x + -0.08

# %%
# Create a scatter plot with a regression line for Generosity
x_values = data_agg['Happiness Score']
y_values = data_agg['Generosity']

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel('Happiness Score')
plt.ylabel('Generosity')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
plt.show()
# Out:
# The r-squared is: 0.03251477107023962
# y = 0.02x + 0.13
